# %%
import sys, os
from os.path import join, abspath, exists, pardir
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import array as a
from astropy.table import Table
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Add, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from matplotlib.colors import LogNorm

# %%
train_path = "data/train.csv"
test_path = "data/test.csv"
valid_path = "data/validation.csv"

rng = np.random.default_rng(42)

# %% [markdown]
# # Train-Validation Split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.utils import to_categorical
training_data = Table.read(train_path)

classes = np.unique(training_data["class"])
class_d = dict(zip(classes,np.arange(len(classes))))
def class_to_num(c): return class_d[c]
f = np.vectorize(class_to_num)

training_data["class_id"] = f(training_data["class"])

x_train = np.stack([a(training_data[col].astype(float)) for col in ([c for c in training_data.colnames if c not in ["ID","class","class_id"]])]).T

nb_classes = len(classes)

y_train = to_categorical(a(training_data["class_id"]), nb_classes)

# x_train, y_train

# %%
# load validation

valid_data = Table.read(valid_path)
valid_data["class_id"] = f(valid_data["class"])

x_valid = np.stack([a(valid_data[col].astype(float)) for col in ([c for c in valid_data.colnames if c not in ["ID","class","class_id"]])]).T
y_valid = to_categorical(a(valid_data["class_id"]), nb_classes)

# %%
# load testing

test_data = Table.read(test_path)
test_data["class_id"] = f(test_data["class"])

x_test = np.stack([a(test_data[col].astype(float)) for col in ([c for c in test_data.colnames if c not in ["ID","class","class_id"]])]).T
y_test = to_categorical(a(test_data["class_id"]), nb_classes)

# %%
# normalize using the train stats

for c in range(x_train.shape[1]):
    mean, std = np.mean(x_train[:,c]), np.std(x_train[:,c])
    x_train[:,c] = (x_train[:,c]-mean) / std
    x_valid[:,c] = (x_valid[:,c]-mean) / std
    x_test[:,c] = (x_test[:,c]-mean) / std

# %% [markdown]
# # Model-building

# %%
es = EarlyStopping(patience=15,monitor="val_loss",mode="min",restore_best_weights=True,verbose=1)

# %%
from tensorflow.keras import metrics
f1_metric = metrics.F1Score(average='weighted')

# %%
inputs = Input(shape=(x_train.shape[1],))

initializer="HeNormal"
dense_activation = LeakyReLU(negative_slope=0.01)

a = 0.2 # dropout rate

neuron_num_1 = 128
neuron_num_2 = 64

regularizer = "L2"
# regularizer=None
kernel_regularizer=regularizer,

# input MLP
di = Dense(neuron_num_1,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(inputs)
di = BatchNormalization()(di)
di = Dropout(a)(di)
# di = Dense(neuron_num_1,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(di)
# di = Dropout(a)(di)
di = Dense(neuron_num_2,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(di)
di = BatchNormalization()(di)

# # residual block
d = Dropout(a)(di)
d = Dense(neuron_num_2,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(d)
d = BatchNormalization()(d)
d = Dropout(a)(d)
# d = Dense(neuron_num_2,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(d)
# d = Dropout(a)(d)
res = Add()([d,di])

# # after residual
# d2 = Dense(neuron_num_2,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(res)
# d2 = Dropout(a)(d2)
# d2 = Dense(neuron_num_2,activation=dense_activation, kernel_regularizer=regularizer, kernel_initializer=initializer)(d2)
# d2 = Dropout(a)(d2)

# # skip connection
# comb = Add()([di,d2])
comb = Add()([di,res])


# output = Dense(nb_classes,activation="softmax", kernel_initializer=initializer)(di)
output = Dense(nb_classes,activation="softmax", kernel_initializer=initializer)(comb)

model = Model(inputs=inputs,outputs=output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      3,200 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      4,160 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64)        │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64)        │          0 │ batch_normalizat… │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 9)         │        585 │ add_1[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 17,225 (67.29 KB)
#  Trainable params: 16,713 (65.29 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
model.save("final_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
LR = 0.0001

model = Model(inputs=inputs,outputs=output)
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=LR), metrics=['accuracy',f1_metric])
history = model.fit(x_train, y_train, epochs=500, verbose=1, validation_data=(x_valid,y_valid), batch_size=32, callbacks=[es])
# Out:
# Epoch 1/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.2422 - f1_score: 0.2392 - loss: 8.2688 - val_accuracy: 0.4855 - val_f1_score: 0.5319 - val_loss: 5.9013
# Epoch 2/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4007 - f1_score: 0.3983 - loss: 6.0958 - val_accuracy: 0.5471 - val_f1_score: 0.5888 - val_loss: 4.9715
# Epoch 3/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.4422 - f1_score: 0.4398 - loss: 5.1397 - val_accuracy: 0.5748 - val_f1_score: 0.6137 - val_loss: 4.2165
# Epoch 4/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.4731 - f1_score: 0.4702 - loss: 4.3402 - val_accuracy: 0.6023 - val_f1_score: 0.6379 - val_loss: 3.5591
# Epoch 5/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.4963 - f1_score: 0.4935 - loss: 3.6760 - val_accuracy: 0.6154 - val_f1_score: 0.6505 - val_loss: 3.0342
# Epoch 6/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.5191 - f1_score: 0.5164 - loss: 3.1384 - val_accuracy: 0.6201 - val_f1_score: 0.6552 - val_loss: 2.6232
# Epoch 7/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.5374 - f1_score: 0.5340 - loss: 2.7134 - val_accuracy: 0.6340 - val_f1_score: 0.6651 - val_loss: 2.2900
# Epoch 8/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5493 - f1_score: 0.5457 - loss: 2.3959 - val_accuracy: 0.6420 - val_f1_score: 0.6737 - val_loss: 2.0324
# Epoch 9/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.5686 - f1_score: 0.5657 - loss: 2.1219 - val_accuracy: 0.6483 - val_f1_score: 0.6793 - val_loss: 1.8329
# Epoch 10/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.5764 - f1_score: 0.5736 - loss: 1.9199 - val_accuracy: 0.6589 - val_f1_score: 0.6872 - val_loss: 1.6642
# Epoch 11/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5935 - f1_score: 0.5903 - loss: 1.7389 - val_accuracy: 0.6243 - val_f1_score: 0.6641 - val_loss: 1.5665
# Epoch 12/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.5962 - f1_score: 0.5934 - loss: 1.6052 - val_accuracy: 0.6435 - val_f1_score: 0.6785 - val_loss: 1.4384
# Epoch 13/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.6111 - f1_score: 0.6087 - loss: 1.4804 - val_accuracy: 0.6215 - val_f1_score: 0.6638 - val_loss: 1.3783
# Epoch 14/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6149 - f1_score: 0.6125 - loss: 1.3917 - val_accuracy: 0.6307 - val_f1_score: 0.6712 - val_loss: 1.2962
# Epoch 15/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - accuracy: 0.6334 - f1_score: 0.6313 - loss: 1.2937 - val_accuracy: 0.6649 - val_f1_score: 0.6975 - val_loss: 1.1994
# Epoch 16/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6297 - f1_score: 0.6270 - loss: 1.2357 - val_accuracy: 0.6745 - val_f1_score: 0.7060 - val_loss: 1.1364
# Epoch 17/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6354 - f1_score: 0.6337 - loss: 1.1923 - val_accuracy: 0.6868 - val_f1_score: 0.7157 - val_loss: 1.0829
# Epoch 18/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6432 - f1_score: 0.6411 - loss: 1.1350 - val_accuracy: 0.6615 - val_f1_score: 0.6974 - val_loss: 1.0821
# Epoch 19/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6498 - f1_score: 0.6479 - loss: 1.0946 - val_accuracy: 0.6796 - val_f1_score: 0.7115 - val_loss: 1.0215
# Epoch 20/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.6558 - f1_score: 0.6540 - loss: 1.0576 - val_accuracy: 0.6667 - val_f1_score: 0.7039 - val_loss: 1.0143
# Epoch 21/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6640 - f1_score: 0.6623 - loss: 1.0226 - val_accuracy: 0.6763 - val_f1_score: 0.7107 - val_loss: 0.9819
# Epoch 22/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6668 - f1_score: 0.6652 - loss: 0.9975 - val_accuracy: 0.6796 - val_f1_score: 0.7137 - val_loss: 0.9615
# Epoch 23/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.6681 - f1_score: 0.6669 - loss: 0.9753 - val_accuracy: 0.6784 - val_f1_score: 0.7132 - val_loss: 0.9523
# Epoch 24/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.6744 - f1_score: 0.6731 - loss: 0.9464 - val_accuracy: 0.7015 - val_f1_score: 0.7296 - val_loss: 0.9138
# Epoch 25/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.6767 - f1_score: 0.6750 - loss: 0.9380 - val_accuracy: 0.6789 - val_f1_score: 0.7129 - val_loss: 0.9331
# Epoch 26/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6808 - f1_score: 0.6794 - loss: 0.9236 - val_accuracy: 0.7019 - val_f1_score: 0.7301 - val_loss: 0.8810
# Epoch 27/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6780 - f1_score: 0.6767 - loss: 0.9106 - val_accuracy: 0.6562 - val_f1_score: 0.6986 - val_loss: 0.9427
# Epoch 28/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.6845 - f1_score: 0.6836 - loss: 0.8892 - val_accuracy: 0.6763 - val_f1_score: 0.7115 - val_loss: 0.9029
# Epoch 29/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6899 - f1_score: 0.6885 - loss: 0.8807 - val_accuracy: 0.6873 - val_f1_score: 0.7216 - val_loss: 0.8768
# Epoch 30/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.6919 - f1_score: 0.6906 - loss: 0.8633 - val_accuracy: 0.6780 - val_f1_score: 0.7130 - val_loss: 0.8924
# Epoch 31/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6912 - f1_score: 0.6901 - loss: 0.8593 - val_accuracy: 0.6676 - val_f1_score: 0.7048 - val_loss: 0.8957
# Epoch 32/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - accuracy: 0.6982 - f1_score: 0.6972 - loss: 0.8412 - val_accuracy: 0.6695 - val_f1_score: 0.7065 - val_loss: 0.8944
# Epoch 33/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.6984 - f1_score: 0.6972 - loss: 0.8316 - val_accuracy: 0.6528 - val_f1_score: 0.6974 - val_loss: 0.8947
# Epoch 34/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.6990 - f1_score: 0.6980 - loss: 0.8246 - val_accuracy: 0.7004 - val_f1_score: 0.7322 - val_loss: 0.8279
# Epoch 35/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7006 - f1_score: 0.6991 - loss: 0.8262 - val_accuracy: 0.6597 - val_f1_score: 0.7021 - val_loss: 0.8849
# Epoch 36/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.6972 - f1_score: 0.6960 - loss: 0.8255 - val_accuracy: 0.7112 - val_f1_score: 0.7390 - val_loss: 0.8105
# Epoch 37/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7079 - f1_score: 0.7068 - loss: 0.8022 - val_accuracy: 0.6617 - val_f1_score: 0.7049 - val_loss: 0.8720
# Epoch 38/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7058 - f1_score: 0.7050 - loss: 0.8022 - val_accuracy: 0.6986 - val_f1_score: 0.7305 - val_loss: 0.8220
# Epoch 39/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7057 - f1_score: 0.7045 - loss: 0.7986 - val_accuracy: 0.6641 - val_f1_score: 0.7043 - val_loss: 0.8747
# Epoch 40/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.7107 - f1_score: 0.7096 - loss: 0.7883 - val_accuracy: 0.6778 - val_f1_score: 0.7164 - val_loss: 0.8431
# Epoch 41/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7093 - f1_score: 0.7083 - loss: 0.7908 - val_accuracy: 0.6941 - val_f1_score: 0.7271 - val_loss: 0.8125
# Epoch 42/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.7089 - f1_score: 0.7077 - loss: 0.7818 - val_accuracy: 0.6890 - val_f1_score: 0.7254 - val_loss: 0.8168
# Epoch 43/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.7093 - f1_score: 0.7082 - loss: 0.7884 - val_accuracy: 0.6856 - val_f1_score: 0.7206 - val_loss: 0.8240
# Epoch 44/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7130 - f1_score: 0.7120 - loss: 0.7773 - val_accuracy: 0.6784 - val_f1_score: 0.7135 - val_loss: 0.8461
# Epoch 45/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.7138 - f1_score: 0.7128 - loss: 0.7667 - val_accuracy: 0.6696 - val_f1_score: 0.7096 - val_loss: 0.8342
# Epoch 46/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 27s 13ms/step - accuracy: 0.7120 - f1_score: 0.7109 - loss: 0.7690 - val_accuracy: 0.6636 - val_f1_score: 0.7044 - val_loss: 0.8501
# Epoch 47/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7129 - f1_score: 0.7118 - loss: 0.7622 - val_accuracy: 0.6761 - val_f1_score: 0.7123 - val_loss: 0.8302
# Epoch 48/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7157 - f1_score: 0.7148 - loss: 0.7613 - val_accuracy: 0.7000 - val_f1_score: 0.7327 - val_loss: 0.7925
# Epoch 49/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.7162 - f1_score: 0.7152 - loss: 0.7586 - val_accuracy: 0.6705 - val_f1_score: 0.7103 - val_loss: 0.8335
# Epoch 50/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.7181 - f1_score: 0.7173 - loss: 0.7576 - val_accuracy: 0.6804 - val_f1_score: 0.7168 - val_loss: 0.8287
# Epoch 51/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7163 - f1_score: 0.7153 - loss: 0.7459 - val_accuracy: 0.6631 - val_f1_score: 0.6978 - val_loss: 0.8478
# Epoch 52/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7199 - f1_score: 0.7189 - loss: 0.7481 - val_accuracy: 0.6954 - val_f1_score: 0.7300 - val_loss: 0.7893
# Epoch 53/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7153 - f1_score: 0.7144 - loss: 0.7534 - val_accuracy: 0.6825 - val_f1_score: 0.7165 - val_loss: 0.8173
# Epoch 54/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7192 - f1_score: 0.7185 - loss: 0.7436 - val_accuracy: 0.6932 - val_f1_score: 0.7279 - val_loss: 0.7856
# Epoch 55/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7210 - f1_score: 0.7202 - loss: 0.7447 - val_accuracy: 0.6851 - val_f1_score: 0.7218 - val_loss: 0.7949
# Epoch 56/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.7241 - f1_score: 0.7231 - loss: 0.7393 - val_accuracy: 0.6637 - val_f1_score: 0.7055 - val_loss: 0.8358
# Epoch 57/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.7265 - f1_score: 0.7258 - loss: 0.7336 - val_accuracy: 0.7060 - val_f1_score: 0.7373 - val_loss: 0.7732
# Epoch 58/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7238 - f1_score: 0.7228 - loss: 0.7331 - val_accuracy: 0.6670 - val_f1_score: 0.7068 - val_loss: 0.8302
# Epoch 59/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.7208 - f1_score: 0.7200 - loss: 0.7390 - val_accuracy: 0.6950 - val_f1_score: 0.7301 - val_loss: 0.7816
# Epoch 60/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.7260 - f1_score: 0.7252 - loss: 0.7384 - val_accuracy: 0.7023 - val_f1_score: 0.7348 - val_loss: 0.7739
# Epoch 61/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.7206 - f1_score: 0.7197 - loss: 0.7361 - val_accuracy: 0.6977 - val_f1_score: 0.7302 - val_loss: 0.7803
# Epoch 62/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.7192 - f1_score: 0.7183 - loss: 0.7389 - val_accuracy: 0.6730 - val_f1_score: 0.7119 - val_loss: 0.8115
# Epoch 63/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7307 - f1_score: 0.7298 - loss: 0.7240 - val_accuracy: 0.6832 - val_f1_score: 0.7218 - val_loss: 0.7995
# Epoch 64/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7245 - f1_score: 0.7237 - loss: 0.7264 - val_accuracy: 0.6840 - val_f1_score: 0.7206 - val_loss: 0.8102
# Epoch 65/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7256 - f1_score: 0.7245 - loss: 0.7286 - val_accuracy: 0.6971 - val_f1_score: 0.7319 - val_loss: 0.7719
# Epoch 66/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7259 - f1_score: 0.7250 - loss: 0.7202 - val_accuracy: 0.6798 - val_f1_score: 0.7183 - val_loss: 0.8054
# Epoch 67/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.7270 - f1_score: 0.7260 - loss: 0.7299 - val_accuracy: 0.7005 - val_f1_score: 0.7303 - val_loss: 0.7766
# Epoch 68/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.7234 - f1_score: 0.7225 - loss: 0.7281 - val_accuracy: 0.6769 - val_f1_score: 0.7138 - val_loss: 0.8099
# Epoch 69/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7294 - f1_score: 0.7286 - loss: 0.7126 - val_accuracy: 0.7003 - val_f1_score: 0.7354 - val_loss: 0.7631
# Epoch 70/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.7268 - f1_score: 0.7259 - loss: 0.7188 - val_accuracy: 0.7087 - val_f1_score: 0.7399 - val_loss: 0.7596
# Epoch 71/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7254 - f1_score: 0.7243 - loss: 0.7133 - val_accuracy: 0.6870 - val_f1_score: 0.7235 - val_loss: 0.7901
# Epoch 72/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7257 - f1_score: 0.7248 - loss: 0.7228 - val_accuracy: 0.6826 - val_f1_score: 0.7203 - val_loss: 0.7950
# Epoch 73/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.7332 - f1_score: 0.7322 - loss: 0.7114 - val_accuracy: 0.6706 - val_f1_score: 0.7089 - val_loss: 0.8114
# Epoch 74/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.7328 - f1_score: 0.7318 - loss: 0.7085 - val_accuracy: 0.6970 - val_f1_score: 0.7308 - val_loss: 0.7760
# Epoch 75/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.7282 - f1_score: 0.7274 - loss: 0.7192 - val_accuracy: 0.6450 - val_f1_score: 0.6901 - val_loss: 0.8494
# Epoch 76/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.7277 - f1_score: 0.7271 - loss: 0.7145 - val_accuracy: 0.6904 - val_f1_score: 0.7267 - val_loss: 0.7774
# Epoch 77/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.7328 - f1_score: 0.7321 - loss: 0.7061 - val_accuracy: 0.6886 - val_f1_score: 0.7256 - val_loss: 0.7832
# Epoch 78/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7273 - f1_score: 0.7266 - loss: 0.7200 - val_accuracy: 0.6940 - val_f1_score: 0.7272 - val_loss: 0.7839
# Epoch 79/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7296 - f1_score: 0.7286 - loss: 0.7134 - val_accuracy: 0.6451 - val_f1_score: 0.6924 - val_loss: 0.8379
# Epoch 80/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7273 - f1_score: 0.7264 - loss: 0.7110 - val_accuracy: 0.7048 - val_f1_score: 0.7370 - val_loss: 0.7654
# Epoch 81/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.7321 - f1_score: 0.7316 - loss: 0.7080 - val_accuracy: 0.6676 - val_f1_score: 0.7115 - val_loss: 0.8163
# Epoch 82/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.7337 - f1_score: 0.7331 - loss: 0.7004 - val_accuracy: 0.6928 - val_f1_score: 0.7284 - val_loss: 0.7841
# Epoch 83/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.7373 - f1_score: 0.7365 - loss: 0.7042 - val_accuracy: 0.6860 - val_f1_score: 0.7229 - val_loss: 0.7899
# Epoch 84/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.7274 - f1_score: 0.7266 - loss: 0.7128 - val_accuracy: 0.6741 - val_f1_score: 0.7119 - val_loss: 0.8074
# Epoch 85/500
# 1390/1390 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.7336 - f1_score: 0.7327 - loss: 0.7073 - val_accuracy: 0.6860 - val_f1_score: 0.7238 - val_loss: 0.7876
# Epoch 85: early stopping
# Restoring model weights from the end of the best epoch: 70.

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 5))

ax2 = ax1.twinx()

train_loss = history.history['loss']
val_loss = history.history['val_loss']

ax1.plot(train_loss, label='Train Loss')
ax1.plot(val_loss, label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

train_acc = history.history['f1_score']
val_acc = history.history['val_f1_score']

ax2.plot(train_acc, label='Train F1', linestyle="dashed")
ax2.plot(val_acc, label='Validation F1', linestyle="dashed")
ax2.set_ylabel('F1')
ax2.legend()

plt.title('Loss per Epoch')
plt.grid(True)
# plt.savefig("5_layer_20n_0_0001_lr_no_dropout.png",bbox_inches="tight",dpi=300)
plt.show()

# %%
test_loss, test_accuracy, test_f1 = model.evaluate(x_test,y_test)
# Out:
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7077 - f1_score: 0.7380 - loss: 0.7573

# %%
probas = model.predict(x_test)
preds  = np.argmax(probas,axis=1)
Y_test_dense = np.argmax(y_test, axis=1)
# Out:
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
print("Accuracy:",accuracy_score(Y_test_dense,preds))
print("Precision:",precision_score(Y_test_dense,preds,average="macro"))
print("Recall:",recall_score(Y_test_dense,preds,average="macro"))
f1 = f1_score(Y_test_dense,preds,average="macro")
print("F1:",f1)
# Out:
# Accuracy: 0.7095891894819508
# Precision: 0.637085802603066
# Recall: 0.7437415640536306
# F1: 0.6649765071813358

# %%
id_to_class = dict(zip(np.arange(len(classes)),classes))
def formatter(x, pos):
  return id_to_class[int(x+0.5)-1]

# %%
conf = confusion_matrix(Y_test_dense,preds)
plt.figure(figsize=(7,6))
plt.title(f"Model Test Run (n={len(y_test)}, F1={f1:.4f})")
_=sns.heatmap(conf,annot=True,fmt='d')
plt.gca().xaxis.set_major_formatter(formatter)
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig("/content/model_confusion_matrix.png",dpi=300,bbox_inches="tight")
